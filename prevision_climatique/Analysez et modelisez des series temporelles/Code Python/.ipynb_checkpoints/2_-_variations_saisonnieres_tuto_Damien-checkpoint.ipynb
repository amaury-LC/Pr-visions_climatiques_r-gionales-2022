# %% [markdown]
# # Corrigez une série temporelle des variations saisonnières

# %% [markdown]
# ## Exemple Y = Tendance + Saisonnalité + Résidu

# %%
import math
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
from seasonal import fit_seasons
from numpy import linalg as LA

# %%
pip install seasonal
# Out:
# Requirement already satisfied: seasonal in c:\users\utilisateur\anaconda3\lib\site-packages (0.3.1)
# Requirement already satisfied: numpy in c:\users\utilisateur\anaconda3\lib\site-packages (from seasonal) (1.20.1)
# Requirement already satisfied: scipy in c:\users\utilisateur\anaconda3\lib\site-packages (from seasonal) (1.6.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
mois = list(range(1, 38)) # dernier 37 : janvier de la 3ème année

# %%
# Tendance
T = [(1+ 0.5 * t) for t in mois]
plt.plot(T)

# %%
# Saisonnalité
S = [2*math.sin((t-1)*(2*math.pi)/12) for t in mois]
plt.plot(S)

# %%
# Résidu
# modélisé par un bruit gaussien d'écart type 0.5
epsilon = np.random.normal(0,0.5,37)
plt.plot(epsilon)

# %% [markdown]
# # regardons la distribution de $\varepsilon $

# %%
sns.distplot(epsilon)
# Out:
# C:\Users\utilisateur\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
TB=[T[i]+epsilon[i] for i in range(len(T))]
# Courbe corrigée des variation saisonnièr
plt.title("Courbe sans les variations saisonnières")
sns.lineplot(x=mois, y=TB)
# Out:
# <AxesSubplot:title={'center':'Courbe sans les variations saisonnières'}>

# %% [markdown]
# # affichons la courbe totale

# %%
courbe=[T[i]+S[i]+epsilon[i] for i in range(len(T))]
df=pd.DataFrame(zip(courbe,TB,T),columns=['courbe totale', 'tendance+bruit','tendance'])

# %%
plt.title("Courbe  totale+ courbe sans saison + tendance")
sns.lineplot(x=mois, y=courbe, color='red')
sns.lineplot(x=mois, y=TB)
sns.lineplot(x=mois, y =T, color='green')
# Out:
# <AxesSubplot:title={'center':'Courbe  totale+ courbe sans saison + tendance'}>

# %%
plt.title("Etude de la série Temporelle")
sns.lineplot(data=df)
# Out:
# <AxesSubplot:title={'center':'Etude de la série Temporelle'}>

# %%
t = [i for i in range(1,38)]

for i in range(12):
    su = np.repeat(0, repeats=12)
    su[i] = 1
    s = np.tile(su, 37 // len(su) + 1)[:37]
    vars()['s' + str(i+1)] = s

# %%
(np.array([t, s1, s2, s3, s4, s5, s6, s7, s8, s9, s10, s11, s12]).transpose()).shape
# Out:
# (37, 13)

# %%
#df[['courbe totale']].head()
len(s1)
(np.array([t, s1, s2, s3, s4, s5, s6, s7, s8, s9, s10, s11, s12]).transpose()).shape
# Out:
# (37, 13)

# %%
from sklearn import linear_model

reg = linear_model.LinearRegression(fit_intercept=False)
reg.fit(np.array([t, s1, s2, s3, s4, s5, s6, s7, s8, s9, s10, s11, s12]).transpose(), courbe)
# Out:
# LinearRegression(fit_intercept=False)

# %%
courbe
# Out:
# [2.165231636573042,
#  3.0045576885362517,
#  3.450812075795535,
#  5.626253634274072,
#  5.749053040274687,
#  4.7541030483887186,
#  4.114077319609762,
#  4.4172024950970465,
#  4.246672894855441,
#  3.7135426292068874,
#  4.391862265962291,
#  5.0719834231425915,
#  7.5917824900236885,
#  9.731004315550862,
#  9.04955186074905,
#  11.295004549266466,
#  10.030021154120153,
#  11.189449512750933,
#  10.58252699158803,
#  10.066547134800649,
#  10.282720586564603,
#  9.442238838706697,
#  11.35317843429889,
#  13.158529463046003,
#  12.681570442612985,
#  14.426831947017435,
#  16.028242081139922,
#  17.316378433449533,
#  17.971381848972367,
#  17.05839463089103,
#  17.264214059157013,
#  15.191364425577863,
#  14.775672605686374,
#  15.905070225036223,
#  16.47742343719179,
#  17.013994475533902,
#  19.62986905732653]

# %%
np.mean(reg.coef_)
# Out:
# 1.0302852318670468

# %%
a = np.mean(reg.coef_)
b = reg.coef_[0]
c = reg.coef_[1:13] - a

# %%
y_cvs =courbe-(c[0]*s1+c[1]*s2+c[2]*s3+c[3]*s4+c[4]*s5+c[5]*s6+c[6]*s7+c[7]*s8+c[8]*s9+
                        c[9]*s10+c[10]*s11+c[11]*s12)

# %%
y_cvs
# Out:
# array([ 2.0394629 ,  1.87833435,  2.36187205,  3.12699075,  3.90487102,
#         3.65211131,  3.85181586,  5.40952982,  5.85503688,  5.89599875,
#         6.01313491,  6.17859566,  7.46601375,  8.60478097,  7.96061183,
#         8.79574166,  8.18583913, 10.08745778, 10.32026554, 11.05887446,
#        11.89108457, 11.62469496, 12.97445108, 14.2651417 , 12.5558017 ,
#        13.3006086 , 14.93930206, 14.81711555, 16.12719983, 15.9564029 ,
#        17.0019526 , 16.18369175, 16.38403659, 18.08752635, 18.09869608,
#        18.12060672, 19.50410032])

# %%
plt.title('courbe desaisonnalisée avec reg lineaire')
sns.lineplot(x=mois, y =y_cvs)
# Out:
# <AxesSubplot:title={'center':'courbe desaisonnalisée avec reg lineaire'}>

# %%
plt.title('Tendances avec un regplot')
sns.regplot(x=mois, y=y_cvs)
# Out:
# <AxesSubplot:title={'center':'Tendances avec un regplot'}>

# %%
reglin=linear_model.LinearRegression()

# %%
df1=pd.DataFrame(zip(mois,list(y_cvs)), columns=['mois','y_cvs'])

# %%
X=np.array(mois)
y=list(df1['y_cvs'])

# %%
reglin.fit(X.reshape(-1,1),y)
# Out:
# LinearRegression()

# %%
y_pred=reglin.predict(X.reshape(-1,1))

# %%
plt.title('Tendance récupérée avec la Regression lineaire')
yy=[reglin.intercept_*i+reglin.coef_ for i in mois]
sns.lineplot(x=mois,y=y_pred, color='red')
# Out:
# <AxesSubplot:title={'center':'Tendance récupérée avec la Regression lineaire'}>

# %%
reglin.coef_
reglin.intercept_
# Out:
# 1.0302852318670475

# %% [markdown]
# # donc a la main

# %%
yy=[(reglin.intercept_*i+reglin.coef_)[0] for i in mois]
plt.plot(yy)

# %%
fig = sm.tsa.seasonal_decompose(courbe, freq=12).plot()
# Out:
# <ipython-input-31-016b473f0198>:1: FutureWarning: the 'freq'' keyword is deprecated, use 'period' instead
#   fig = sm.tsa.seasonal_decompose(courbe, freq=12).plot()

# %%
type(courbe)
# Out:
# list

# %% [markdown]
# # avec fit season

# %%
seasons, trended = fit_seasons(courbe)

# %%
plt.plot(trended)

# %% [markdown]
# # calculons les différences

# %%
diff=[TB[i]-y_cvs[i] for i in range(len(TB))]

# %%
LA.norm(diff, ord=2)
# Out:
# 1.6098943219110213

# %%
biais=sum([abs(y_cvs[i]-TB[i]) for i in range(len(TB))])/len(TB)

# %%
biais
# Out:
# 0.19815235897399291

# %%
plt.title("comparaison données reelles et estimation")
plt.plot(TB)
plt.plot(y_cvs)
